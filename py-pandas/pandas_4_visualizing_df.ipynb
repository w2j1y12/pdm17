# %% [markdown]
# <a href="https://colab.research.google.com/github/w2j1y12/pdm17/blob/main/py-pandas/pandas_4_visualizing_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Python module 3. **pandas**

# %% [markdown]
# # Using pandas

# %% [markdown]
# * [10 Minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/10min.html)
# * [Pandas tutorial with interactive exercises](https://www.kaggle.com/pistak/pandas-tutorial-with-interactive-exercises)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  # work for Jupyter notebook or lab

# %%
# Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:
dates = pd.date_range('20210927', periods=6)
dates
# Out:
# DatetimeIndex(['2021-09-27', '2021-09-28', '2021-09-29', '2021-09-30',
#                '2021-10-01', '2021-10-02'],
#               dtype='datetime64[ns]', freq='D')

# %%
# head()
np.random.seed(1234)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2021-09-27  0.471435 -1.190976  1.432707 -0.312652
# 2021-09-28 -0.720589  0.887163  0.859588 -0.636524
# 2021-09-29  0.015696 -2.242685  1.150036  0.991946
# 2021-09-30  0.953324 -2.021255 -0.334077  0.002118
# 2021-10-01  0.405453  0.289092  1.321158 -1.546906
# 2021-10-02 -0.202646 -0.655969  0.193421  0.553439

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# #### [도전] 데이터프레임 df의 평균(mean(0))과 표준편차를 이용한 그래프
# - 평균에 대한 꺽은선그래프
# - 평균과 표준편차를 이용한 막대그래프
# > x-축은 A,B,C,D

# %%
# df의 평균(mean(0))과 표준편차를 이용한 바그래프
bar_labels = df.columns
# plot bars
plt.bar(bar_labels, df.mean(0), yerr=df.std(0), color='rgbc')
plt.show()
# 그래프의 텍스트 설명이 사라짐
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# ***

# %% [markdown]
# ## pandas의 데이터 시각화 (Visualization)

# %%
df
# Out:
#                    A         B         C         D
# 2021-09-27  0.471435 -1.190976  1.432707 -0.312652
# 2021-09-28 -0.720589  0.887163  0.859588 -0.636524
# 2021-09-29  0.015696 -2.242685  1.150036  0.991946
# 2021-09-30  0.953324 -2.021255 -0.334077  0.002118
# 2021-10-01  0.405453  0.289092  1.321158 -1.546906
# 2021-10-02 -0.202646 -0.655969  0.193421  0.553439

# %% [markdown]
# ### 꺽은선 그래프

# %%
df['A'].plot(marker='o', c='r', ms=8)
plt.show()
# plt.show()하면 위에 글자같은게 사라짐

# %%
df['C'].plot(marker='D', c='g', ms=8)  # set figsize
plt.show()

# %%
df.plot(y='D', marker='*', c='r', ms=12)   # x-축은 날짜인덱스
# 위에는 데이터 프레임에서 특정 행을 지정해 열의 값을 출력했는데
# 이 그래프는 y축을 D열의 값으로 해서 출력

# %%
# 두 개의 그래프를 한 축에 그리기
# df['A','D'].plot(marker='o', c='r', ms=8)
# error - A와 D가 리스트로 묶어야 함
# df[['A','D']].plot(marker='o', c='r', ms=8)  # works!, change colors
df[['A','D']].plot(style=['ro-', 'bD-'], ms=8)
# pandas plot multiple markers
# marker 여러 개 넣는 거 해보기

# %%
df.plot(y=['A','C'], marker='o')

# %% [markdown]
# ### 산포도 (Scatter graph)

# %%
df
# Out:
#                    A         B         C         D
# 2021-09-27  0.471435 -1.190976  1.432707 -0.312652
# 2021-09-28 -0.720589  0.887163  0.859588 -0.636524
# 2021-09-29  0.015696 -2.242685  1.150036  0.991946
# 2021-09-30  0.953324 -2.021255 -0.334077  0.002118
# 2021-10-01  0.405453  0.289092  1.321158 -1.546906
# 2021-10-02 -0.202646 -0.655969  0.193421  0.553439

# %%
df.plot(kind='scatter',x='C',y='A', color='r', marker='o', s=32)  
# x,y 지정

# %%
df.plot(kind='scatter',x='B',y='C', color='blue', marker='d', s=50)  
# scatter 두 개의 데이터의 상관성을 알 수 있음

# %% [markdown]
# ### 바 그래프

# %%
df['A'].plot.bar()

# %%
df['D'].plot.bar()

# %%
df.plot(kind='bar', y='D', rot=55)
# rot - 레이블을 각도 제어

# %% [markdown]
# #### 다중 바그래프

# %%
df.plot(kind='bar',y=['A','C','D'])
# kind -  그래프 타입 지정

# %% [markdown]
# #### 평균/표준편차 그래프

# %%
df.mean(0), df.std(0), df.columns
# 열에 대한 평균과 표준편차
# Out:
# (A    0.153779
#  B   -0.822438
#  C    0.770472
#  D   -0.158096
#  dtype: float64, A    0.585516
#  B    1.247079
#  C    0.699548
#  D    0.898456
#  dtype: float64, Index(['A', 'B', 'C', 'D'], dtype='object'))

# %%
# plot bars
# bar_labels = df.columns
# plt.bar(bar_labels, df.mean(0), yerr=df.std(0))
df.mean(0).plot.bar(yerr=df.std(0), rot=0)

# %% [markdown]
# ---

# %% [markdown]
# ### 그래프 이어 그리기

# %%
x1 = np.arange(0.0, 5.0, 0.01)
y1 = np.sin(2*np.pi*x1)
plt.figure(figsize=(10,4))
# 그래프(그림) 크기
plt.plot(x1, y1, 'o', ms = 4)

# %%
x1.shape, y1.shape
# x와 y의 데이터 개수가 같음 -> 에러 발생 x
# Out:
# ((500,), (500,))

# %% [markdown]
# #### pandas 데이터프레임을 이용한 그래프

# %%
df = pd.DataFrame(dict(sine=y1), index=x1, columns=['sine'])
df.head()
# Out:
#           sine
# 0.00  0.000000
# 0.01  0.062791
# 0.02  0.125333
# 0.03  0.187381
# 0.04  0.248690

# %%
df.tail()
# 5 포함 x
# Out:
#           sine
# 4.95 -0.309017
# 4.96 -0.248690
# 4.97 -0.187381
# 4.98 -0.125333
# 4.99 -0.062791

# %%
len(df)
# Out:
# 500

# %%
pre_size = int(len(df) * 0.8)
post_size = len(df) - pre_size
pre, post = df.iloc[0:pre_size], df.iloc[pre_size:len(df)]
# iloc - 인덱스 지정해서 슬라이싱
print(len(pre), len(post))
# Out:
# 400 100

# %%
post.shape
# Out:
# (100, 1)

# %%
post2 = post + np.random.normal(scale=0.2, size=len(post)).reshape(-1,1)
# 어떠한 신호에 가우시안 잡음을 넣어줌

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(0, len(pre)), pre, 'g', label="pre")
# pre 그래프(처음 sin 함수)를 초록색으로
plt.plot(np.arange(len(pre), len(pre) + len(post)), post, 'b', marker='.', label="post")
# pre부터 뒤 20%를 그리는데 잡음없는 파란색으로
plt.plot(np.arange(len(pre), len(pre) + len(post)), post2, 'r', label="post2")
# 80-100% 구간을 잡음이 들어간 sin 함수 빨간색으로
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %% [markdown]
# #### post  post2를 동시에 그려서 두 그래프를 비교해보시오.
#
# - subplot 사용
# - 위, 아래로 그려서 비교

# %%
plt.figure(figsize=(10,5))
plt.subplot(211).set_title("post")
plt.plot(post, 'b')
plt.subplot(212).set_title("post2")
plt.plot(post2, 'r')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
a = fig.add_subplot(211)
b = fig.add_subplot(212)
a.plot(np.arange(len(pre), len(pre) + len(post)), post, 'b', label="post")
b.plot(np.arange(len(pre), len(pre) + len(post)), post2, 'r', label="post2")
plt.show()
